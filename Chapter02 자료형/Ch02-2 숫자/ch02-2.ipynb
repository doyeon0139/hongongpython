# %% [markdown]
# > ### 02-2 숫자
# ---

# %% [markdown]
# #### 시작하기 전에
# 소수점이 없는 숫자를 ***정수형***이라하고, 소수점이 있는 숫자를 ***실수형***이라 한다.
# * 정수(integer) : 0, -1 273 ...
# * 실수(float) : 0.0, 3.141592, -1.2...

# %% [markdown]
# > 숫자의 종류 : int(정수), float(부동소수점)등, 자료형에 따라 값에 대한 해석이 달라진다.
# http://www.binaryconvert.com

# %%
i = 1
print(i)
print(type(i))

f = 1.0
print(f)
print(type(f))
# Out:
# 1
# <class 'int'>
# 1.0
# <class 'float'>

# %% [markdown]
# > 정수형(Integer)

# %%
print(-123, 0, 47839, 1_000_000)

# 기수법(numeral system) : binary(2), octal(8), decimal(10), hexadecimal(16)

number = 10

print(bin(number))
print(oct(number))
print(number)
print(hex(number))

n = 10
print(n.bit_length(), bin(n))
# Out:
# -123 0 47839 1000000
# 0b1010
# 0o12
# 10
# 0xa
# 4 0b1010

# %% [markdown]
# > 실수형(float)

# %%
# print(-1.2, .0, 1.0, 3.14)

#  부동 소수점 표현방식 
print(3.14E2)
print(3.14 * 10 ** 2)
print(314e-2)
print(1e-4)

# 실수 값의 오차 : 유효범위(정밀도)
print(0.1 * 3)
print(1.2 - 0.1)
print(0.1 * 0.1)

print(0.1 * 3 == 0.3)  #False
# Out:
# 314.0
# 314.0
# 3.14
# 0.0001
# 0.30000000000000004
# 1.0999999999999999
# 0.010000000000000002
# False

# %% [markdown]
# > 숫자 연산자 ( +, -, *, /, **, %, //, =)

# %%
print('3 ÷ 2 = ', 3/2)

print(1/1) # 나누기를 하면 실수형으로 반환된다.
# 자바
# print(1/(float)1) 

y = 50 - 5 * 6 / 4
print(y)

print(15 /2)
print(15 //2) # 몫만
print(15 % 2)
# print(15 % 2 == 0)

# 짝수/홀수 판별
n = 8
if n % 2 == 0:
    print("짝수 입니다")
else :
    print('홀수 입니다')

# 제곱 제곱근
print(5 ** 2)
print(2 ** (1/2))
print(9 ** (1/2))  # 루트는 (1/2) 으로 나타냄
# Out:
# 3 ÷ 2 =  1.5
# 1.0
# 42.5
# 7.5
# 7
# 1
# 짝수 입니다
# 25
# 1.4142135623730951
# 3.0

# %% [markdown]
# > 원의 반지름을 사용자로부터 입력받아 둘레와 면적을 구하는 프로그램 작성(circle.py)

# %%
from math import pi

def circle_round(num):
    result = num * 2 * pi
    return result

def circle(num):
    result = num ** 2 * pi  
    return result

n = int(input("원의 반지름을 입력하세요"))

answer = circle(n)
round = circle_round(n)

print('원의 넓이는 {}이고,\n원의 둘레는 {} 입니다.'.format (answer, round))
# Out:
# 원의 넓이는 314.1592653589793이고,
# 원의 둘레는 62.83185307179586 입니다.

# %%
n = int(input('원의 반지름을 입력하세요'))
pi = 3.14

answer = pi * n ** 2
round = pi * n * 2

print('원의 넓이는 {}이고,\n원의 둘레는 {} 입니다.'.format (answer, round))
# Out:
# 원의 넓이는 314.0이고,
# 원의 둘레는 62.800000000000004 입니다.

# %%
from math import pi

def circle(num):
    result = pi * num**2
    return result 

def triangle(num1,num2):
    result = num1*num2/2
    return result

def rect(num1,num2):
    result = num1*num2
    return result
    



t = int(input("도형을 고르시오 1.원 2.삼각형 3.사각형"))

if t == 1:
    num = float(input("반지름을 입력하세요"))
    result = circle(num)
    print ("반지름 {}인 원의 넓이는 {}입니다.".format (num,result))

elif t == 2:
    num1 = int(input("밑변을 입력하세요"))
    num2 = int(input("높이를 입력하세요"))
    result = triangle(num1,num2)
    print("밑변이 {}그리고 높이가 {}의 삼각형의 넓이는 {}입니다.".format (num1,num2,result))

elif t == 3:
    num1 = int(input("가로길이를 입력하세요"))
    num2 = int(input("세로길이를 입력하세요"))
    result = rect(num1,num2)
    print("가로길이 {}, 세로길이 {}의 사각형 넓이는 {}입니다." .format (num1, num2, result))

else:
    print("보기에 없는 도형번호입니다.")
# Out:
# 반지름 10.0인 원의 넓이는 314.1592653589793입니다.
