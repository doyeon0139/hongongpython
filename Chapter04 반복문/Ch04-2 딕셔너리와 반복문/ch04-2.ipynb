# %% [markdown]
# #### 딕셔너리와 반복문
# ---
# #### 시작하기 전에
# **리스트**가 '인덱스를 기반으로 값을 저장하는 것'이라면 ***딕셔너리***는 '키(key)'를 기반으로 저장한다.

# %%
'012'
[0,1,2]
(0,1,2)
{0,1,2}
{'0',}


print('문자열', type(''))
print('리스트', type([]))
print('튜플', type(()))
print('셋', type({0,}))
print('딕셔너리', type({}))
# Out:
# 문자열 <class 'str'>
# 리스트 <class 'list'>
# 튜플 <class 'tuple'>
# 셋 <class 'set'>
# 딕셔너리 <class 'dict'>

# %% [markdown]
# > 딕셔너리 선언하기

# %%
{}
# 딕셔너리 = {키:값, 키:값, 키:값, ....}
dic = \
{
    'A':10, 
    'B':20, 
    'C':30, 
    1:40, 
    False:50
}
print(dic)

my_movie = {
    'name':'어벤져스 엔드게임',
    'type':'히어로 무비'
}
print(my_movie) 

my_info = ['김철수', '27', '010-1234-5678', '서울 강남구', 174]

my_info = {
    'name':'김철수',
    'age':'27',
    'phone':'010-1234-5678',
    'addr':'서울 강남구',
    'iq': 174
}
# Out:
# {'A': 10, 'B': 20, 'C': 30, 1: 40, False: 50}
# {'name': '어벤져스 엔드게임', 'type': '히어로 무비'}

# %% [markdown]
# > 딕셔너리 요소에 접근하기

# %%
my_info = {
    'name':'김철수',
    'age':'27',
    'phone':'010-1234-5678',
    'addr':'서울 강남구',
    'iq': 174
}

print(my_info['iq'])

di = {'02':'서울', '051':'부산', '053':'대구', '032': '인천'}
# 순서가 없다 노시퀀셜, 키이름이 중복되면 안된다
print(di['02'])
# Out:
# 174
# 서울

# %%
district = {
    2:['종로', '용산', '강남','마포','영등포'],
    51:'해운대',
    53: '달성구',    
    32:['부평','계양']
}
print(district)

# 접근 방법
district[51]
district[2][3]

# 값 변경
district[53] = '달서'
print(district)
# Out:
# {2: ['종로', '용산', '강남', '마포', '영등포'], 51: '해운대', 53: '달성구', 32: ['부평', '계양']}
# {2: ['종로', '용산', '강남', '마포', '영등포'], 51: '해운대', 53: '달서', 32: ['부평', '계양']}

# %% [markdown]
# > 딕셔너리에 요소 추가/제거 하기

# %%
#  딕셔너리[추가할 키] = 추가할 값

tv = {}
print('요소 추가 전 : tv =', tv)

# 요소 추가
tv['product_name'] = 'LG Smart TV 2022'
tv['serial_number'] = '20220107STV'
tv['price'] = 1_500_000

print('요소 추가 후: tv = ', tv)
# Out:
# 요소 추가 전 : tv = {}
# 요소 추가 후: tv =  {'product_name': 'LG Smart TV 2022', 'serial_number': '20220107STV', 'price': 1500000}

# %%
dictionary = {
    'interpreter': '프로그래밍 소스 코드를 곧바로 실행해 주는 프로그램',
    'variable' : '값을 저장할 때 사용하는 식별자',
    'function' : '어떤 동작 또는 기능을 하도록 기술하는 코드'
}

search_word = input('IT 검색 : ')

#                 [interpreter]
if search_word in dictionary.keys():
    print(search_word + ':', dictionary[search_word])
else :
    print(f'"{search_word}"에 대한 검색 결과 없습니다.')

# IT 용어 추가
dictionary['keword'] = '언어 내에서 문법적인 용도로 사용되고 있는 단어'

print('[keyword]추가 : ', dictionary)
# Out:
# "gg"에 대한 검색 결과 없습니다.
# [keyword]추가 :  {'interpreter': '프로그래밍 소스 코드를 곧바로 실행해 주는 프로그램', 'variable': '값을 저장할 때 사용하는 식별자', 'function': '어떤 동작 또는 기능을 하도록 기술하는 코드', 'keword': '언어 내에서 문법적인 용도로 사용되고 있는 단어'}

# %%
# 딕셔너리에 요소 제거하기
# del 딕셔너리[삭제할 키]

songs = {
    '아이유':['에잇','너의 의미','밤편지','내 손을 잡아'],
    '이문세':['소녀','옛사랑','광화문 연가','소녀'],
    '블랙핑크':['마지막처럼','불장난', 'So Hot'],
    'BTS':['Dynamite','전하지 못한 진심', 'My Universe']
}
print('요소 제거 이전 : \nsongs =', songs)

# 요소를 제거
del songs['이문세']
print('요소 제거 이후 : \nsongs =', songs)

# So Hot 제거
del songs['블랙핑크'][2]
print('요소 제거 이후 : \nsongs =', songs)
# Out:
# 요소 제거 이전 :
# songs = {'아이유': ['에잇', '너의 의미', '밤편지', '내 손을 잡아'], '이문세': ['소녀', '옛사랑', '광화문 연가', '소녀'], '블랙핑크': ['마지막처럼', '불장난', 'So Hot'], 'BTS': ['Dynamite', '전하지 못한 진심', 'My Universe']}
# 요소 제거 이후 :
# songs = {'아이유': ['에잇', '너의 의미', '밤편지', '내 손을 잡아'], '블랙핑크': ['마지막처럼', '불장난', 'So Hot'], 'BTS': ['Dynamite', '전하지 못한 진심', 'My Universe']}
# 요소 제거 이후 :
# songs = {'아이유': ['에잇', '너의 의미', '밤편지', '내 손을 잡아'], '블랙핑크': ['마지막처럼', '불장난'], 'BTS': ['Dynamite', '전하지 못한 진심', 'My Universe']}

# %% [markdown]
# > KeyError 예외

# %%
li = [1,2,3]
# li[3] #IndexError: list index out of range

di ={'A+':95, 'A':90, 'B+':85, 'B':80, 'D':None}
print(di['D'])
di['C+'] #KeyError: 'C+'
# Out:
# None
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20844/3591430424.py in <module>
#       4 di ={'A+':95, 'A':90, 'B+':85, 'B':80, 'D':None}
#       5 print(di['D'])
# ----> 6 di['C+']
#       7
#
# KeyError: 'C+'

# %% [markdown]
# > 딕셔너리 내부에 키(key)가 있는지 확인하기 : in, get

# %%
#  키가 존재하는지 확인하고 값에 접근한다.

di ={'A+':95, 'A':90, 'B+':85, 'B':80, 'D':60}
print(di)

key = input('등급을 입력하세요: ')

# key가 있는지
if key in di:
    print('{}학점은 {}점 이상입니다.'.format(key, di))

# key가 없는지
else :
    print('해당 등급이 없습니다.')
    res = input('등록해 드릴까요(y/n) : ')
    if res == 'y':
        value = int(input('등급에 해당하는 점수를 입력하세요'))
        di[key] = value 
        print(di)
        print('학점이 정상적으로 등록되었습니다.')
# Out:
# {'A+': 95, 'A': 90, 'B+': 85, 'B': 80, 'D': 60}
# 해당 등급이 없습니다.
# {'A+': 95, 'A': 90, 'B+': 85, 'B': 80, 'D': 60, 'c': 70}
# 학점이 정상적으로 등록되었습니다.

# %% [markdown]
# > 키의 존재와 관련된 get() 함수

# %%
# get() 함수는 딕셔너리 키로 값을 추출, 존재하지 않는 키에 접근할 경우?
# 'KeyError'를 발생시키지 않고, 'None'을 반환

di ={'A+':95, 'A':90, 'B+':85, 'B':80, 'D':60}

di.get('A+')
# di['A+']
print(di['A+'])

# di['C+']
print(di.get('C+'))

if 'C+' not in di:
    print('C+ does not exist')

if di.get('C+') == None :
    print('C+ does not exist')
# Out:
# 95
# None
# C+ does not exist
# C+ does not exist

# %% [markdown]
# > for 반복문 : 딕셔너리와 함께 사용하기

# %%
# for i in '반복객체' : 

di ={'A+':95, 'A':90, 'B+':85, 'B':80, 'D':60}
#   A+ A B+ B D
for grade in di:
    print('{:3s}등급은 {}점 이상'.format(grade, di[grade]))
# Out:
# A+ 등급은 95점 이상
# A  등급은 90점 이상
# B+ 등급은 85점 이상
# B  등급은 80점 이상
# D  등급은 60점 이상

# %%
n = 12345
m = 'abcde'
f = 3.141592

print('n = {:7d}\nm = {:>7s}\nf = {:7.2f}'.format(n,m,f))
# Out:
# n =   12345
# m =   abcde
# f =    3.14
