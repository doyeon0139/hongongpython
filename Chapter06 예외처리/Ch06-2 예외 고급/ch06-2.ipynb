# %% [markdown]
# ### 06-2 예외 고급
# ---
# #### 예외(exception object) 발생시키기

# %% [markdown]
# > raise 구문

# %%
# 타 언어 예외처리 : throw(예외를 던지고) ---> try ~ catch ~ finally 예외를 받아 처리 ...

class Biz_InValidError(Exception):
    def __init__(self, message):
        Exception.__init__(self)
        self.message = message
    def __str__(self) :
        return self.message

# 업무상 데이터가 음수가 입력되면 안되는 상황
# 업무상 데이터가 0이 입력되면 안되는 상황
def biz_method(number):
    '''자연수가 아니면 Biz_InValidError'''
    if number > 0:
        print('유효한 입력입니다')
    else:
        # 자연수가 아닌 경우를 처리
        raise Biz_InValidError('업무상 자연수만 입력해주세요!!!')

print('==============================================================') 

print('프로그램 시작')

data_in = input('정수입력 : ')  
number = int(data_in)

biz_method(number)


print('프로그램 종료')
# Out:
# ==============================================================
# 프로그램 시작
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24248/2876379359.py in <module>
#      23
#      24 data_in = input('정수입력 : ')
# ---> 25 number = int(data_in)
#      26
#      27 biz_method(number)
#
# ValueError: invalid literal for int() with base 10: '0.1'

# %%
# 타 언어 예외처리 : throw(예외를 던지고) ---> try ~ catch ~ finally 예외를 받아 처리 ...

class Biz_InValidError(Exception):
    def __init__(self, message):
        Exception.__init__(self)
        self.message = message
    def __str__(self) :
        return self.message

# 업무상 데이터가 음수가 입력되면 안되는 상황
# 업무상 데이터가 0이 입력되면 안되는 상황
def biz_method(number):
    '''자연수가 아니면 Biz_InValidError'''
    
    if number > 0:
        print('유효한 입력입니다')
    else:
        # 자연수가 아닌 경우를 처리
        raise Biz_InValidError('업무상 자연수만 입력해주세요!!!')

print('==============================================================') 

print('프로그램 시작')

data_in = input('정수입력 : ')  
number = int(data_in)

try:
    
    biz_method(number)
    
except Biz_InValidError as ex_biz:
    print(str(ex_biz))

print('프로그램 종료')
# Out:
# ==============================================================
# 프로그램 시작
# 업무상 자연수만 입력해주세요!!!
# 프로그램 종료
