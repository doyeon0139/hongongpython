# %% [markdown]
# ### 03-2 if ~ else 와 elif 문
# ---
# #### 시작하기 전에
# **두 가지**만 구분되는 실행 흐름 : 오전/오후, 주간/야간, 남/여, 합격/불합격

# %%
# if else 예제 오전/오후

import datetime

curruent = datetime.datetime.now().hour
curruent = int(curruent)

if curruent >= 12 :
    print('오후 입니다.')
else : 
    print('오전 입니다.')
# Out:
# 오전 입니다.

# %% [markdown]
# > elif 구문 : 여러가지 케이스로 분기하고자 할 때

# %%
# 계절별, 요일별...

# 학점 판별
score = 0
grade = ''

score = int(input('점수를 입력하세요 : '))
if score >= 95 :
    grade = 'A+'
elif score >= 90:
    grade = 'A'
elif score >= 85:
    grade = 'B+'
elif score >= 80:
    grade = 'B'
elif score >= 75:
    grade = 'C+'
elif score >= 70:
    grade = 'C'
else:
    grade = 'D'

print('당신의 점수는 {}점이고, 등급은 {}입니다.'.format(score,grade))

# %% [markdown]
# > False로 변환되는 값 : 0, 0.0, 빈 컨테이너, 빈 문자열, None

# %%
import datetime

if 0:        #False
    print('0은 True로 변환')
else:
    print('0은 False로 변환')


if datetime.datetime.now().year == 2022:
    print('True 입니다')

else:
    print('False 입니다.')

bool(None)
# Out:
# 0은 False로 변환
# True 입니다
# False

# %% [markdown]
# > pass 키워드 : 프로그래밍 시 전체 골격을 잡아 놓고 처리 할 내용은 차근차근 구현하고자 할 때

# %%
number = input('정수입력 >')
number = int(number)
if number > 0 :
    # 양수 일 때 : 아직 미구현 상태
    0
else:
    # 음수 일 때 : 아직 미구현 상태
    0

if number > 0:
    pass
else:
    pass

# 예외처리
if number > 0:
    raise NotImplementedError
else :
    raise NotImplementedError
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9188/2721467333.py in <module>
#      15 # 예외처리
#      16 if number > 0:
# ---> 17     raise
#      18 else :
#      19     raise
#
# RuntimeError: No active exception to reraise

# %% [markdown]
# > 사용자로부터 태어난 연도를 입력받아 띠를 리턴해주는 프로그램 작성

# %%
# zodiac = ['🐵','🐔','🐶','🐷','🐭','🐮','🐯','🐰','🐲','🐍','🐴','🐑']

# %%
birth = int(input('태어난 연도를 입력하세요'))

# anymal = ['원숭이', '닭', '개', '돼지', '쥐', '소', '호랑이', '토끼', '용', '뱀', '말', '양']
anymal = ['🐵','🐔','🐶','🐷','🐭','🐮','🐯','🐰','🐲','🐍','🐴','🐑']

a = birth % 12

for i in range(len(anymal)):
    if a == i:
        print('당신의 띠는 {}입니다.'.format(anymal[i]))
# Out:
# 당신의 띠는 🐰입니다.

# %%
zodiac = ['원숭이', '닭', '개', '돼지', '쥐', '소', '호랑이', '토끼', '용', '뱀', '말', '양']
try:
    print(f"당신의 띠는 {zodiac[int(input('태어난 해를 입력하세요'))%12]} 입니다.")
except:
    print("잘못입력했습니다.")
# Out:
# 당신의 띠는 용 입니다.

# %%
zodiac = ['원숭이', '닭', '개', '돼지', '쥐', '소', '호랑이', '토끼', '용', '뱀', '말', '양']
try:
    print(f"당신의 띠는 {zodiac[int(input('태어난 해를 입력하세요'))%12]} 입니다.")

except:
    print("잘못입력했습니다.")
# Out:
# 당신의 띠는 용 입니다.
# ['원숭이', '닭', '개', '돼지', '쥐', '소', '호랑이', '토끼', '용', '뱀', '말', '양']

# %%
dat = ["원숭이", "닭", "개", "돼지", "쥐", "소", "호랑이", "토끼", '용', "뱀", "말", '양']

year = input("태어난 날짜를 입력하세요: ")
year = int(year)
number = year % 12

for a in range(len(dat)):
    if number == a:
        print(dat[a])

# %% [markdown]
# > 현재 계절을 리턴해주는 프로그램 작성

# %%
import datetime

date = datetime.datetime.now().month


   
if 3 <= date <=5:
    print('봄입니다.')
elif 6<= date <= 8:
    print('여름입니다.')
elif 9<= date <= 11:
    print('가을입니다.')
else:
    print('겨울입니다.')
# Out:
# 겨울입니다.

# %%
import datetime as dt
season = ['겨울', '봄','여름', '가을']
m = dt.datetime.now().month
print(f'지금은 {m}월이고 {season[(m%12)//3]}입니다')
# Out:
# 지금은 1월이고 겨울입니다

# %% [markdown]
# > 짝수, 홀수 구분하는 프로그램

# %%
input_data = input('정수입력')

# 마지막 자리 숫자 추출
last_char = input_data[-1]

# 숫자변환
number = int(last_char)

if number == 0 or number == 2 \
or number == 4 or number == 6 or number == 8:
    print('{}(은)는 짝수입니다.'.format(input_data))
else:
    print('{}(은)는 홀수입니다.'.format(input_data))
# Out:
# 3(은)는 홀수입니다.

# %%
input_data = input('정수입력')

# 마지막 자리 숫자 추출
last_char = input_data[-1]

if last_char in '02468':
    print('{}(은)는 짝수입니다.'.format(input_data))
else:
    print('{}(은)는 홀수입니다.'.format(input_data))

# %%
#  % 연산자 사용
if number % 2 == 0:
    print('{}(은)는 짝수입니다.'.format(input_data))
else:
    print('{}(은)는 홀수입니다.'.format(input_data))
