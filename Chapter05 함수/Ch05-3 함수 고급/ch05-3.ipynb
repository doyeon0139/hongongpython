# %% [markdown]
# ### 05-3 함수 고급
# ---
# ***튜플(tuple)***과 ***람다(lanbda)***

# %% [markdown]
# > 튜플(tuple)

# %%
# 튜플 : 함수와 함께 많이 사용되는 리스트와 비슷한 자료형, 
# 한 번 결정된 요소는 바꿀 수 없다.!!!

tu = (10, 20, 30)
tu[0]
tu[0] = 1  #오류

# %%
# 요소를 하나만 가지는 튜플 생성
type([273]) #list
type((273))  #int
type((273,)) #tuple
# Out:
# int

# %%
#  변수 다중 할당
[a, b] = [10, 20]
a
b
(c, d) = [30, 40]
print(a, b, c, d)

a, b, c = [1, 2, 3]
d, e, f = (4, 5, 6)
print(a, b, c, d, e, f)

x = [1,2,3]
a, b, c = x

y = (4, 5, 6)
d, e, f = y

# 괄호 생략
tu = 10, 20, 30
type(tu)

# 변수의 값 교환
a, b = 10, 20
a, b = b, a
a
# Out:
# 10 20 30 40
# 1 2 3 4 5 6
# 20

# %% [markdown]
# > 튜플과 함수

# %%
#  튜플은 함수의 리턴에 많이 사용(여러개의 값을 리턴하고 할당 가능)
def test():
    return(10, 20)

a,b = test()
print(a, b)

# %% [markdown]
# ### 람다(lambda) : 람다표현식(익명함수) <> def

# %% [markdown]
# > 함수의 매개변수로 함수 전달하기

# %%
def call_10_times(func):
    for i in range(10):
        func()

def print_hello():
    print('안녕하세요')

# 함수 콜(매개변수로 함수를 전달)
call_10_times(print_hello) # 함수를 넣었다 뺐다 할 수 있다.
# Out:
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요

# %%
def call_10_times(func):
    for i in range(10):
        func()

#  람다 표현식 적용
call_10_times(lambda : print('hi'))
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi

# %% [markdown]
# > 람다 표현식으로 함수 만들기

# %%
def plus_ten(x):
    return x + 10

plus_ten(1)

# lambda 매개변수 : 리턴값
lambda x : x + 10
# Out:
# 11

# %%
plus_two = lambda x : x + 2
print(type(plus_two))
plus_two(3)


(lambda x : x + 2)(11)
[1, 2, 3][0]
# Out:
# <class 'function'>
# 13

# %%
# [주의사항]
# 람다 표현식 안에서는 변수를 만들 수 없다.

(lambda x : y=10; x+y)(1)
# Out:
#   File "C:\Users\goejt\AppData\Local\Temp/ipykernel_13708/2623522636.py", line 3
#     (lambda x : y=10; x+y)(1)
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# > filter() 함수와 map() 함수

# %%
# 함수를 매개변수로 전달하는 대표적인 표준함수
# map(함수, 리스트)
# filter(함수, 리스트)

def power(item):
    return item + item

def under_3(item):
    return item < 3

li = [1,2,3,4,5]

# map() 함수를 이용
#      = map(power(item)),[1,2,3,4,5]
output = map(power, li)
print('map() 함수의 실행결과')
print(output)
print(list(output))
print()

# filter() 함수를 이용
print('filter() 함수의 실행결과')
output = filter(under_3, li)
print(output)
print(list(output))
# Out:
# map() 함수의 실행결과
# <map object at 0x000002DE941CB730>
# [2, 4, 6, 8, 10]
#
# filter() 함수의 실행결과
# <filter object at 0x000002DE941CA500>
# [1, 2]

# %%
# 인라인 람다
li = [1,2,3,4,5]
output = map(lambda x : x**3 , li)
print(output)
print(list(output))

output = filter(lambda x: x <= 3, li)
print(list(output))
# Out:
# <map object at 0x000002DE941CB010>
# [1, 8, 27, 64, 125]
# [1, 2, 3]

# %% [markdown]
# ### 파일 처리 : 열기, 읽기, 쓰기

# %% [markdown]
# > 파일에 문자열 쓰기

# %%
sb = 'ABCD'.encode()
print(sb, type(sb))

data = b'\x48\x65\x6c\x6c\x6f\x20\x57\x6f\x72\x6c\x64'
print(hex(ord(' '))) # 공백 hex 코드 찾기
print(data.decode())
# Out:
# b'ABCD' <class 'bytes'>
# 0x20
# Hello World

# %%
# 표준입출력 : <stdio> <iostream>
# I.O란 컴퓨터 내부 또는 외부의 장치와 프로그램 간의 데이터를 주고 받는 것
# 단방향 buffer : InputStream, OutputStream

# open('파일경로', '모드')
# 모드 : w(write), a(append), r(read), t(text디폴트), b(binary)

# open() ~ close() 미리 작성하는 습관을 가질 것

# 1.
file = open('../../source/basic.txt', 'wt')

print(type(file))
print(file.name, file.mode)

# 2. 읽기/쓰기
file.write('[hello python programing]\n')
file.write('first line\n')
file.write('second line\n')
file.write('thrid line\n')
file.write('end line\n')

# 3. 파일객체 닫기
file.close()   #항상 먼저 작성하기
# Out:
# <class '_io.TextIOWrapper'>
# ../../source/basic.txt wt

# %%
fo = open('..\\..\\source\\basic.txt', 'r')

# 한꺼번에 읽기
# text = fo.read()
# print(text)

# 한 줄씩 읽어 오기
print(1, fo.readline(), end='')
print(2, fo.readline(), end='')
print(3, fo.readline(), end='')
print(4, fo.readline(), end='')
print(5, fo.readline(), end='')
print(6, bool(fo.readline()))
print(7, bool(''))
print(8, bool(fo.readline()))

fo.close()
# Out:
# 1 [hello python programing]
# 2 first line
# 3 second line
# 4 thrid line
# 5 end line
# 6 False
# 7 False
# 8 False

# %%
f = open('../../source/basic.txt', 'rt')

lines = f.readline()

for i in range(len(lines)):
    print(f'{i+1} line : ', lines[i].strip())   #.strip() : whitespace('',\n) removed

f.close()
# Out:
# 1 line :  [
# 2 line :  h
# 3 line :  e
# 4 line :  l
# 5 line :  l
# 6 line :  o
# 7 line :
# 8 line :  p
# 9 line :  y
# 10 line :  t
# 11 line :  h
# 12 line :  o
# 13 line :  n
# 14 line :
# 15 line :  p
# 16 line :  r
# 17 line :  o
# 18 line :  g
# 19 line :  r
# 20 line :  a
# 21 line :  m
# 22 line :  i
# 23 line :  n
# 24 line :  g
# 25 line :  ]
# 26 line :

# %% [markdown]
# > with 키워드

# %%
try :
    fo = open('basic.txt', mode = 'rt')
    for line in fo:
        print(line)
finally:
    fo.close()

with open('basic.txt', mode='rt') as fi :
    fi.readline()

# %% [markdown]
# > csv 파일을 만들어 사용하기

# %%
# 텍스트를 사용해 데이터를 구조적으로 표현하는 방법 : csv, xml, json
# csv 파일 : 한 줄에 하나의 데이터를 나타내며, 각각의 줄은 ','(쉼표)로 데이터를 구분
# 김철수, 178, 65

import random

first_names = '김이박최정장강조윤임한오서신'
last_names = '가나다라마바사아자차카파타하'

with open('info.csv', 'w', encoding='UTF-8') as f:
    for i in range(10):
        first = random.choice(first_names)
        last = random.choice(last_names) + random.choice(last_names)
        name = first + last

        height = random.randrange(140, 200)
        weight = random.randrange(40, 120)
        f.write('{}, {}, {}\n'.format(name, height, weight))

# %%
# BMI(비만도) : 몸무게/키(m)의 제곱

with open('info.csv', 'r', encoding='UTF-8') as fo:
    for line in fo:
        (name, height, weight) = line.strip().split(', ')
        # 데이터가 유효한지 검사
        if(not name) or (not weight) or (not height):
            continue
        # BMI 계산
        bmi = int(weight) / (int(height)/100)**2
        result = ''
        if bmi >= 25:
            result = '비만'
        elif bmi >= 23:
            result = '과체중'
        elif bmi >= 18:
            result = '정상'
        else:
            result = '저체중'

        str_out = '\n'.join([
            '이름: {}', 
            '몸무게 : {}', 
            '키 : {}', 
            'BMI : {}',
            '결과 : {}' 
            ]).format(name, weight, height, int(bmi), result)

        print(str_out)
        print()
# Out:
# 이름: 서아아
# 몸무게 : 82
# 키 : 149
# BMI : 36
# 결과 : 비만
#
# 이름: 정파바
# 몸무게 : 117
# 키 : 176
# BMI : 37
# 결과 : 비만
#
# 이름: 오마라
# 몸무게 : 71
# 키 : 141
# BMI : 35
# 결과 : 비만
#
# 이름: 장라바
# 몸무게 : 80
# 키 : 174
# BMI : 26
# 결과 : 비만
#
# 이름: 김사마
# 몸무게 : 42
# 키 : 162
# BMI : 16
# 결과 : 저체중
#
# 이름: 정다차
# 몸무게 : 65
# 키 : 165
# BMI : 23
# 결과 : 과체중
#
# 이름: 박하파
# 몸무게 : 77
# 키 : 141
# BMI : 38
# 결과 : 비만
#
# 이름: 박가마
# 몸무게 : 101
# 키 : 157
# BMI : 40
# 결과 : 비만
#
# 이름: 조아다
# 몸무게 : 63
# 키 : 192
# BMI : 17
# 결과 : 저체중
#
# 이름: 서사다
# 몸무게 : 75
# 키 : 177
# BMI : 23
# 결과 : 과체중

# %% [markdown]
# > 바이너리 파일

# %%
from urllib import request

target = request.urlopen('https://mblogthumb-phinf.pstatic.net/MjAxOTEyMTNfMjUz/MDAxNTc2MjIwODEzMzkx.UNzRUpOUUEs-O5VEbMUg7R-QV2ULHUw_nw1IGjm281cg.DQunTVbmd7sul6R0Jo7zjOw4i_DKj-XDaFOsOgiO3l4g.JPEG.ssledkb/1576220818850.jpg?type=w800')
bin_file = target.read()
# print(bin_file)

with open('..\\..\\source\\dog.jpg', 'wb') as fb:
    fb.write(bin_file)
